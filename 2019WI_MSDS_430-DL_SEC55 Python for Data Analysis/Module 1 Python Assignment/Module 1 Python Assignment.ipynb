# %% [markdown]
# # MSDS 430 Module 1 Python Assignment

# %% [markdown]
# #### In this assignment you will complete the following exercises and submit your notebook (ipynb file) to Canvas. Your file should include all output, i.e. run each cell and save your file before submitting.  In this course we will use only python 3.0+

# %%
# Anything that starts with 'hash' symbol are considered as comments and not executed.
# Run the codes in this current cell. The three lines are defining three variables, the first one a string, and next two
# are numerals, one an integer and the next one is a floating point numeral. 
# Python defined variables are global and hence can be recalled later on in any other cell
f = 'first' # this is a string, assigned to f
x1 = 5      # this is an integer numeric value, assigned to x1
x2 = 4.3    # this is a numeric value, assigned x2
x3 = True   # this is a boolean value, assigned to x3
x4=0        # this is a zero value and not a null value, assigned to x4
x5=None     # this is a Null in python and has nothing defined in the named place of x5.
# all the above defined variables can be used later on in the iPython notebook
# if you want to check the data type of these you can use type(variable)

# %% [markdown]
# Problem 1 (1 pt.): Why the following print statement, print 'This is my first Python print execution' does not work.  How will you fix it?

# %%
print 'This is my first Python print execution.'
# Out:
#   File "<ipython-input-2-c542cb438972>", line 1
#     print 'This is my first Python print execution.'
#                                                    ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('This is my first Python print execution.')?

# %%
print ('This is my first Python print execution.')
# Out:
# This is my first Python print execution.

# %%
# Execute the command below as is, and explain what has {} has achieved in the output.
# Also we are seeing for the first time .format, an object of print. Objects are methods applicable to a parent function.
# For more details about powerful print options to play with see: https://realpython.com/python-f-strings/ 
# Note that you are using the variables f, x1, x2 defined(executed) from the above cell
# (1 pt.)
print("This is my {}! print execution using format value stored in a variable, and it is {}!".format(f,x2))

# check what happens when x2 is replaced by x5 vs. x2 is not replaced at all, as a curious play.
# Out:
# This is my first! print execution using format value stored in a variable, and it is 4.3!

# %%
print("This is my {} code in Paython! I'll print execution using format value stored in a variable, and it is {}!".format(f,x5))
# Out:
# This is my first code in Paython! I'll print execution using format value stored in a variable, and it is None!

# %% [markdown]
# Problem 3 (1 pts.): If you want to insert a cell below and move to that cell, what is the keyboard command? What is the keyboard command for executing the cell?
#
# Note that all keyboard commands are decipherable by clicking on the keyboard icon below 'help'.

# %% [markdown]
# Answer:
# <br>**Esc** to activate command mode and type __b__ to insert a new cell below and click ***down*** arrow to move down. Type **Ctr** + **Enter** to execute the code.
# <br> I used Markdown to type this answer.

# %% [markdown]
# Problem 4 (1 pts.): List the top five keyboard commands you think are useful to speed up your iPython notebook execution

# %% [markdown]
# Answer:
# <br>
# 1. **shift + enter** run cell, select below
# 2. **ctrl + enter** run cell
# 3. **a** insert cell above
# 4. **b** insert cell below
# 5. **Ctr+/**  to comment multiple lines

# %% [markdown]
# Problem 5 (1 pts.): Within an iPython notebook, how will you get help on any Python command?

# %% [markdown]
# Answer:
# <br>Go to **help** or type __h__ to see command shortcuts.

# %% [markdown]
# Problem 6 (1 pts.): What are the top 5 magic commands that you feel are useful to interact with your operating system or Python execution?

# %%
# Here are the magic commands:
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# Answer:
# <br>
# 1. **%time, %timeit and %%time** Do you want to know how much time your code needs to run?
# 2. **%magic** To access a general description of available magic functions, including some examples
# 3. **%lsmagic** List currently available magic functions
# 4. **%history** Print input history with most recent last
# 5. **%config** configure IPython
# Reference: https://ipython.readthedocs.io/en/stable/interactive/magics.html

# %% [markdown]
# Problem 7 (1 pts.): From the interactive interpreter (also called the terminal or command prompt on a Mac or command prompt on Windows) on your computer, find the product of any two numbers. Take a screenshot and insert your screenshot in the cell below.

# %%
# Those instructions might help for future students.
# First get the python.exe location
import os
import sys
os.path.dirname(sys.executable)
# Out:
# 'C:\\Users\\asidd\\AppData\\Local\\Continuum\\anaconda3'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Problem 8 (1 pts.): How to get get help about any command using "tab".
# Insert a cell below and write the notes on how to do this.

# %% [markdown]
# Answer:
# <br>
# 1. **shift + Tab** whenever you have a function whose working you are unsure about, you have the Notebook look it up for you by pressing Shift + Tab inside the parentheses
# 2. **Tab** Completion - when you press tab it completes what you are typing as what it is
# <br>
# <br>
# Here is more about tab (not related to the assignment)
# **Tab** to indent multiple lines by selecting them and then pressing Tab
# **Shift + Tab** to de-indent multiple lines by selecting them and then pressing Tab
# <br>
# **Esc** to activate command mode and type **b** to insert a new cell below. Type **Ctr + Enter** to execute the code.

# %% [markdown]
# Problem 9 (1 pts.): Open Anaconda Navigator on your computer and take a screenshot. Insert your screenshot in the cell below.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Problem 10 (1 pts.): From Anaconda, open Spyder. In the iPython console (lower right), find the sum of any two numbers. Take a screenshot and insert your screenshot in the cell below.

# %% [markdown]
# ![image.png](attachment:image.png)
